# %%
#Postorder binary tree

class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

# A function to do Postirder tree traversal
def print_postorder(root):
    if root:

        # Recur on the left subtree
        print_postorder(root.left)

        # Recur on the right subtree
        print_postorder(root.right)

        # Print the value of the current node
        print(root.val, end=" ")

# Contoh pohon biner
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

# Cetak output "Postorder traversal of tree is 4 5 2 1 3"
print("Postorder traversal of tree is", end=" ")
print_postorder(root)
# Out:
# Postorder traversal of tree is 4 5 2 3 1
